# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
import pandas as pd

# %%
classes=["python","R","Machine Learning","Artifical Intelligence", "Data Science"]
class1_student=[45,15,35,25,30]

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.1.1; however, version 23.2.1 is available.
# You should consider upgrading via the 'c:\Users\lenovo\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
plt.pie([1,2])
plt.show()

# %%
plt.pie(class1_student)
plt.show()

# %%
plt.pie(class1_student,labels=classes)
plt.show()

# %%
classes=["python","R","Machine Learning","Artifical Intelligence", "Data Science"]
class1_student=[45,15,35,25,30] 
explode=[0,0,0.2,0,0]
color=["c","b","r","y","g"]
plt.pie(class1_student,labels=classes,explode=explode,colors=color,autopct="%0.2f%%")
plt.show()
