# %%
from matplotlib import pyplot as plt
days=[1,2,3,4,5,6,7,8,9]
temp=[12,34,56,78,98,76,12,45,2]
plt.plot(days,temp)
plt.axis([0,19,0,100])
plt.title("Lahore Temperature")
plt.xlabel("Days")
plt.ylabel("Temprature")
plt.savefig("C:/Users/lenovo/Desktop/Data Visualization/line_plot.png")
plt.plot(days,temp,color="r")
plt.plot(days,temp,color="r",marker="o",linestyle="--",linewidth='3.5')

plt.show()
